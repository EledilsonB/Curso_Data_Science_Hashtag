-- %%
import pandas as pd
import seaborn as sns
-- Out:
-- Error: No connection selected.

-- %%
df = pd.read_csv('../Conceitos_Pandas/train.csv')
display(df.head())
df.tail()
-- Out:
-- Error: No connection selected.

-- %%
print('Linhas x Colunas:', df.shape)
-- Out:
-- Error: No connection selected.

-- %%
# Mostrando Tipos de Dados

df.dtypes
-- Out:
-- Error: No connection selected.

-- %%
display(df.info())
-- Out:
-- Error: No connection selected.

-- %%
display(df.isnull().sum())

print('Cabin valores nulos:', df['Cabin'].isnull().sum())
print('Embarked valores nulos:', df['Embarked'].isnull().sum())
-- Out:
-- Error: No connection selected.

-- %%
df.describe() # -11:13
-- Out:
-- Error: No connection selected.

-- %%
sns.boxplot(df) # -11:13
-- Out:
-- Error: No connection selected.
